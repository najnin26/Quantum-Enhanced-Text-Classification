# %%
# ============================================================
# QBiLSTM-Q on MPQA with Multiple Seeds (42, 123, 256, 512, 999)
# Using 2-Qubit Quantum Circuit
# ============================================================

# !pip install pennylane datasets -q

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, RandomSampler, SequentialSampler
import time, random, re, warnings
import nltk
import pennylane as qml
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score, accuracy_score, confusion_matrix
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModel, get_linear_schedule_with_warmup
from torch.optim import AdamW
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')
nltk.download('stopwords', quiet=True)
stop_words = set(stopwords.words('english'))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

# ============================================================
# SEEDS DEFINITION
# ============================================================

SEEDS = [42, 123, 256, 512, 999]

# ============================================================
# DATA PREPROCESSING (Will be done once)
# ============================================================

def preprocess_text(text):
    text = re.sub(r'\s+', ' ', str(text))
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'#\w+', '', text)
    text = re.sub(r'[^\w\s]', ' ', text)
    text = text.lower()
    return text.strip()

def clean_statement(statement):
    statement = statement.lower()
    statement = re.sub(r'[^\w\s]', ' ', statement)
    statement = re.sub(r'\d+', '', statement)
    words = statement.split()
    words = [w for w in words if w not in stop_words and len(w) > 2]
    return ' '.join(words)

print("\nLoading MPQA dataset...")
ds = load_dataset("jxm/mpqa")
df = ds["train"].to_pandas()

# Clean text
df['cleaned_text'] = df['sentence'].apply(preprocess_text)
df = df[df['cleaned_text'] != '[deleted]']
df = df[df['cleaned_text'] != '[removed]']
df['cleaned_text'] = df['cleaned_text'].apply(clean_statement)
df = df[df['cleaned_text'].str.len() > 3]

# Label encoding
label_encoder = LabelEncoder()
df['label'] = label_encoder.fit_transform(df['label'])
print(f"Classes: {dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))}")

# Use class weights for imbalance
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight('balanced', classes=np.unique(df['label']), y=df['label'])
class_weight_dict = dict(zip(np.unique(df['label']), class_weights))
print(f"Class weights: {class_weight_dict}")

# Tokenization
MODEL_NAME = "microsoft/deberta-v3-base"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
MAX_LEN = 128

tokens = tokenizer(
    df['cleaned_text'].tolist(),
    max_length=MAX_LEN,
    padding="max_length",
    truncation=True,
    return_tensors="pt"
)

input_ids = tokens['input_ids']
attention_masks = tokens['attention_mask']
labels = torch.tensor(df['label'].values)

# Get model hidden size
temp_model = AutoModel.from_pretrained(MODEL_NAME)
HIDDEN_SIZE = temp_model.config.hidden_size
print(f"Model hidden size: {HIDDEN_SIZE}")
del temp_model

# ============================================================
# QUANTUM CIRCUIT (2-qubit as specified)
# ============================================================

dev = qml.device("default.qubit", wires=2)

@qml.qnode(dev, interface='torch')
def quantum_circuit(weights, inputs):
    qml.Hadamard(wires=0)
    qml.Hadamard(wires=1)
    
    qml.RX(inputs[0], wires=0)
    qml.RY(inputs[1], wires=1)
    
    qml.CNOT(wires=[0, 1])
    
    qml.RZ(weights[0], wires=0)
    qml.RZ(weights[1], wires=1)
    
    return qml.expval(qml.PauliZ(0))

# ============================================================
# MODEL DEFINITION
# ============================================================

class QBiLSTM(nn.Module):
    def __init__(self, num_classes=2, hidden_size=1024, dropout_rate=0.3):
        super(QBiLSTM, self).__init__()
        
        self.bert = AutoModel.from_pretrained(MODEL_NAME, torch_dtype=torch.float32)
        
        for param in self.bert.parameters():
            param.requires_grad = True
        
        self.feature_extractor = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_size, 512),
            nn.LayerNorm(512),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(512, 256),
            nn.LayerNorm(256),
            nn.GELU()
        )
        
        self.bilstm = nn.LSTM(
            input_size=256,
            hidden_size=128,
            batch_first=True,
            bidirectional=True,
            dropout=dropout_rate,
            num_layers=2
        )
        self.lstm_norm = nn.LayerNorm(256)
        
        self.quantum_proj = nn.Sequential(
            nn.Linear(256, 32),
            nn.GELU(),
            nn.Dropout(0.2),
            nn.Linear(32, 8),
            nn.GELU(),
            nn.Linear(8, 2),
            nn.Tanh()
        )
        
        self.quantum_weights = nn.Parameter(torch.randn(2, dtype=torch.float32) * 0.01)
        
        self.quantum_expander = nn.Sequential(
            nn.Linear(1, 32),
            nn.GELU(),
            nn.Dropout(0.2),
            nn.Linear(32, 64),
            nn.GELU()
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(256 + 64, 256),
            nn.LayerNorm(256),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(256, 128),
            nn.LayerNorm(128),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.GELU(),
            nn.Dropout(0.1),
            nn.Linear(64, num_classes)
        )
        
        self._init_weights()
    
    def _init_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight, gain=0.5)
                if module.bias is not None:
                    nn.init.zeros_(module.bias)
    
    def quantum_layer(self, features):
        batch_size = features.shape[0]
        quantum_outputs = []
        
        for i in range(batch_size):
            q_input = features[i].detach().cpu().numpy()
            weights = self.quantum_weights.detach().cpu().numpy()
            
            try:
                q_out = quantum_circuit(weights, q_input)
                q_out_tensor = torch.tensor([q_out], dtype=torch.float32).to(features.device)
                q_out_tensor = q_out_tensor * 2.0
            except Exception as e:
                q_out_tensor = torch.zeros(1, device=features.device)
            
            quantum_outputs.append(q_out_tensor)
        
        quantum_outputs = torch.stack(quantum_outputs)
        quantum_outputs = self.quantum_expander(quantum_outputs)
        
        return quantum_outputs
    
    def forward(self, input_ids, attention_mask):
        input_ids = input_ids.long()
        attention_mask = attention_mask.float()
        
        bert_out = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        last_hidden = bert_out.last_hidden_state.float()
        
        mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden.size())
        sum_embeddings = torch.sum(last_hidden * mask_expanded, dim=1)
        sum_mask = torch.sum(mask_expanded, dim=1)
        bert_pooled = sum_embeddings / (sum_mask + 1e-9)
        
        features = self.feature_extractor(bert_pooled)
        
        features_seq = features.unsqueeze(1)
        lstm_out, _ = self.bilstm(features_seq)
        lstm_features = lstm_out[:, -1, :]
        lstm_features = self.lstm_norm(lstm_features)
        
        quantum_input = self.quantum_proj(lstm_features)
        quantum_out = self.quantum_layer(quantum_input)
        
        combined = torch.cat([lstm_features, quantum_out], dim=1)
        output = self.classifier(combined)
        
        return output

# ============================================================
# TRAINING FUNCTION FOR A SINGLE SEED
# ============================================================

def train_for_seed(seed, learning_rate=2e-5, batch_size=32, epochs=10):
    # Set seed
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    
    print(f"\n{'='*80}")
    print(f"TRAINING WITH SEED = {seed}")
    print(f"Learning Rate: {learning_rate}, Batch Size: {batch_size}, Epochs: {epochs}")
    print(f"{'='*80}")
    
    # Split data with current seed
    train_inputs, val_inputs, train_labels, val_labels = train_test_split(
        input_ids, labels, test_size=0.2, random_state=seed, stratify=labels
    )
    train_masks, val_masks, _, _ = train_test_split(
        attention_masks, labels, test_size=0.2, random_state=seed, stratify=labels
    )
    
    # Create dataloaders
    train_dataset = TensorDataset(train_inputs, train_masks, train_labels)
    val_dataset = TensorDataset(val_inputs, val_masks, val_labels)
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Initialize model
    model = QBiLSTM(num_classes=2, hidden_size=HIDDEN_SIZE).to(device)
    
    # Class weights tensor
    class_weights_tensor = torch.tensor([class_weight_dict[0], class_weight_dict[1]], dtype=torch.float32).to(device)
    
    # Optimizer and scheduler
    optimizer = AdamW(model.parameters(), lr=learning_rate, weight_decay=0.01)
    total_steps = len(train_loader) * epochs
    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=int(0.1 * total_steps),
        num_training_steps=total_steps
    )
    
    # Track metrics
    train_losses = []
    train_accs = []
    val_losses = []
    val_accs = []
    
    best_val_acc = 0
    best_f1 = 0
    best_precision = 0
    best_recall = 0
    best_val_loss = 0
    final_train_acc = 0
    best_confusion_matrix = None
    
    for epoch in range(epochs):
        # Training
        model.train()
        total_train_loss = 0
        train_preds = []
        train_labels_list = []
        
        for batch in train_loader:
            b_input_ids, b_mask, b_labels = [b.to(device) for b in batch]
            
            optimizer.zero_grad()
            logits = model(b_input_ids, b_mask)
            loss = F.cross_entropy(logits, b_labels, weight=class_weights_tensor)
            
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            scheduler.step()
            
            total_train_loss += loss.item()
            preds = torch.argmax(logits, dim=1)
            train_preds.extend(preds.cpu().numpy())
            train_labels_list.extend(b_labels.cpu().numpy())
        
        avg_train_loss = total_train_loss / len(train_loader)
        train_acc = accuracy_score(train_labels_list, train_preds)
        
        train_losses.append(avg_train_loss)
        train_accs.append(train_acc)
        
        # Validation
        model.eval()
        val_preds = []
        val_labels_list = []
        total_val_loss = 0
        
        with torch.no_grad():
            for batch in val_loader:
                b_input_ids, b_mask, b_labels = [b.to(device) for b in batch]
                logits = model(b_input_ids, b_mask)
                loss = F.cross_entropy(logits, b_labels, weight=class_weights_tensor)
                total_val_loss += loss.item()
                preds = torch.argmax(logits, dim=1)
                val_preds.extend(preds.cpu().numpy())
                val_labels_list.extend(b_labels.cpu().numpy())
        
        avg_val_loss = total_val_loss / len(val_loader)
        val_acc = accuracy_score(val_labels_list, val_preds)
        val_f1 = f1_score(val_labels_list, val_preds, average='weighted')
        val_precision = precision_score(val_labels_list, val_preds, average='weighted', zero_division=0)
        val_recall = recall_score(val_labels_list, val_preds, average='weighted', zero_division=0)
        
        val_losses.append(avg_val_loss)
        val_accs.append(val_acc)
        
        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {avg_train_loss:.4f} | Train Acc: {train_acc:.4f} | Val Loss: {avg_val_loss:.4f} | Val Acc: {val_acc:.4f} | F1: {val_f1:.4f}")
        
        # Save best model
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_f1 = val_f1
            best_precision = val_precision
            best_recall = val_recall
            best_val_loss = avg_val_loss
            final_train_acc = train_acc
            best_confusion_matrix = confusion_matrix(val_labels_list, val_preds)
    
    print(f"\n📊 Final Results for Seed {seed}:")
    print(f"   Best Val Acc: {best_val_acc:.4f}")
    print(f"   F1-Score: {best_f1:.4f}")
    print(f"   Precision: {best_precision:.4f}")
    print(f"   Recall: {best_recall:.4f}")
    
    return {
        'seed': seed,
        'best_val_accuracy': best_val_acc,
        'final_val_accuracy': val_accs[-1] if val_accs else best_val_acc,
        'final_train_accuracy': final_train_acc,
        'f1_score': best_f1,
        'precision': best_precision,
        'recall': best_recall,
        'val_loss': best_val_loss,
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accuracies': train_accs,
        'val_accuracies': val_accs,
        'confusion_matrix': best_confusion_matrix,
        'predictions': val_preds if 'val_preds' in locals() else [],
        'true_labels': val_labels_list if 'val_labels_list' in locals() else []
    }

# ============================================================
# RUN TRAINING FOR ALL SEEDS
# ============================================================

print("\n" + "="*80)
print("QBiLSTM-Q MODEL ON MPQA DATASET - MULTIPLE SEEDS")
print(f"Model: {MODEL_NAME} (hidden size={HIDDEN_SIZE})")
print(f"Quantum Circuit: 2-qubit with Hadamard, RX, RY, CNOT, RZ gates")
print(f"Seeds to test: {SEEDS}")
print("="*80)

all_results = []

for seed in SEEDS:
    result = train_for_seed(
        seed=seed,
        learning_rate=2e-5,
        batch_size=32,
        epochs=10
    )
    all_results.append(result)

# ============================================================
# STATISTICS ACROSS SEEDS
# ============================================================

metrics = ["best_val_accuracy", "final_val_accuracy", "final_train_accuracy",
           "f1_score", "precision", "recall"]

stats = {}
for metric in metrics:
    values = [r[metric] for r in all_results]
    stats[metric] = {
        "mean": np.mean(values),
        "std":  np.std(values),
        "min":  np.min(values),
        "max":  np.max(values),
    }

stats_df = pd.DataFrame(stats).round(4)
print("\n" + "="*80)
print("STATISTICS ACROSS 5 SEEDS (Quantum Model)")
print("="*80)
print(stats_df)

# ============================================================
# RESULTS SUMMARY TABLE
# ============================================================

print("\n" + "="*80)
print("DETAILED RESULTS FOR ALL SEEDS")
print("="*80)
print(f"{'Seed':<8} {'Best Val Acc':<14} {'Final Val Acc':<14} {'Train Acc':<12} {'Precision':<12} {'Recall':<12} {'F1-Score':<12} {'Val Loss':<10}")
print("-"*100)
for r in all_results:
    print(f"{r['seed']:<8} {r['best_val_accuracy']:<14.4f} {r['final_val_accuracy']:<14.4f} {r['final_train_accuracy']:<12.4f} {r['precision']:<12.4f} {r['recall']:<12.4f} {r['f1_score']:<12.4f} {r['val_loss']:<10.4f}")

# Save results to CSV
results_df = pd.DataFrame([{
    'Seed': r['seed'],
    'Best Val Acc': r['best_val_accuracy'],
    'Final Val Acc': r['final_val_accuracy'],
    'Train Acc': r['final_train_accuracy'],
    'Precision': r['precision'],
    'Recall': r['recall'],
    'F1-Score': r['f1_score'],
    'Val Loss': r['val_loss']
} for r in all_results])
results_df.to_csv('mpqa_multi_seed_results.csv', index=False)
print(f"\n✅ Results saved to mpqa_multi_seed_results.csv")

# ============================================================
# PLOT TRAINING CURVES
# ============================================================

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Validation accuracy
ax = axes[0, 0]
for r in all_results:
    ax.plot(r["val_accuracies"], marker="o", label=f"Seed {r['seed']}", linewidth=2)
ax.set_title("Validation Accuracy Across Seeds", fontsize=14, fontweight='bold')
ax.set_xlabel("Epoch", fontsize=12)
ax.set_ylabel("Accuracy", fontsize=12)
ax.legend(loc='best')
ax.grid(True, alpha=0.3)
ax.set_ylim([0.5, 1.0])

# Training accuracy
ax = axes[0, 1]
for r in all_results:
    ax.plot(r["train_accuracies"], marker="s", label=f"Seed {r['seed']}", linewidth=2)
ax.set_title("Training Accuracy Across Seeds", fontsize=14, fontweight='bold')
ax.set_xlabel("Epoch", fontsize=12)
ax.set_ylabel("Accuracy", fontsize=12)
ax.legend(loc='best')
ax.grid(True, alpha=0.3)
ax.set_ylim([0.5, 1.0])

# Validation loss
ax = axes[1, 0]
for r in all_results:
    ax.plot(r["val_losses"], marker="o", label=f"Seed {r['seed']}", linewidth=2)
ax.set_title("Validation Loss Across Seeds", fontsize=14, fontweight='bold')
ax.set_xlabel("Epoch", fontsize=12)
ax.set_ylabel("Loss", fontsize=12)
ax.legend(loc='best')
ax.grid(True, alpha=0.3)

# Training loss
ax = axes[1, 1]
for r in all_results:
    ax.plot(r["train_losses"], marker="s", label=f"Seed {r['seed']}", linewidth=2)
ax.set_title("Training Loss Across Seeds", fontsize=14, fontweight='bold')
ax.set_xlabel("Epoch", fontsize=12)
ax.set_ylabel("Loss", fontsize=12)
ax.legend(loc='best')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("mpqa_training_curves.pdf", dpi=150, bbox_inches='tight')
plt.show()
print("✅ Training curves saved to mpqa_training_curves.pdf")

# ============================================================
# CONFUSION MATRICES
# ============================================================

num_seeds = len(all_results)
fig, axes = plt.subplots(1, num_seeds, figsize=(5*num_seeds, 4))
if num_seeds == 1:
    axes = [axes]

for idx, r in enumerate(all_results):
    cm = r["confusion_matrix"]
    sns.heatmap(cm, annot=True, fmt='d', ax=axes[idx], cmap='Blues', cbar=False)
    axes[idx].set_title(f"Seed {r['seed']}", fontsize=12, fontweight='bold')
    axes[idx].set_xlabel('Predicted', fontsize=10)
    axes[idx].set_ylabel('Actual', fontsize=10)
    
    # Add accuracy text
    axes[idx].text(0.5, -0.15, f"Acc: {r['best_val_accuracy']:.3f}", 
                   transform=axes[idx].transAxes, ha='center', fontsize=10)

plt.suptitle("Confusion Matrices for Different Seeds", fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig("mpqa_confusion_matrices.pdf", dpi=150, bbox_inches='tight')
plt.show()
print("✅ Confusion matrices saved to mpqa_confusion_matrices.pdf")

# ============================================================
# PERFORMANCE BOXPLOT
# ============================================================

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Accuracy boxplot
accuracies = [r['best_val_accuracy'] for r in all_results]
bp1 = ax1.boxplot([accuracies], labels=['QBiLSTM-Q'], patch_artist=True)
bp1['boxes'][0].set_facecolor('lightblue')
ax1.set_title('Best Validation Accuracy Distribution', fontsize=12, fontweight='bold')
ax1.set_ylabel('Accuracy', fontsize=11)
ax1.grid(True, alpha=0.3)
ax1.set_ylim([0.5, 1.0])

# Add individual points
ax1.scatter(np.ones(len(accuracies)) * 1, accuracies, 
            color='red', s=50, zorder=3, label='Individual seeds')
ax1.legend()

# Multi-metrics boxplot
metrics_data = [
    [r['best_val_accuracy'] for r in all_results],
    [r['f1_score'] for r in all_results],
    [r['precision'] for r in all_results],
    [r['recall'] for r in all_results]
]
bp2 = ax2.boxplot(metrics_data, labels=['Accuracy', 'F1', 'Precision', 'Recall'], 
                  patch_artist=True)
for patch, color in zip(bp2['boxes'], ['lightblue', 'lightgreen', 'lightcoral', 'lightyellow']):
    patch.set_facecolor(color)
ax2.set_title('Performance Metrics Distribution', fontsize=12, fontweight='bold')
ax2.set_ylabel('Score', fontsize=11)
ax2.grid(True, alpha=0.3)
ax2.set_ylim([0.5, 1.0])

plt.tight_layout()
plt.savefig("mpqa_performance_boxplot.pdf", dpi=150, bbox_inches='tight')
plt.show()
print("✅ Performance boxplot saved to mpqa_performance_boxplot.pdf")

# ============================================================
# QUANTUM CIRCUIT VISUALIZATION
# ============================================================

print("\n" + "="*80)
print("QUANTUM CIRCUIT ARCHITECTURE")
print("="*80)
try:
    # Draw the quantum circuit
    sample_weights = torch.randn(2)
    sample_inputs = torch.tensor([0.5, 0.5])
    print(qml.draw(quantum_circuit, expansion_strategy="device")(sample_weights, sample_inputs))
except Exception as e:
    print(f"Quantum circuit visualization not available: {e}")

# Create circuit diagram manually
print("\nQuantum Circuit Diagram:")
print("   ┌──────────┐     ┌──────────┐")
print("0: ┤ Hadamard ├─────┤ RX(θ0)  ├─┐")
print("   └──────────┘     └──────────┘ │")
print("   ┌──────────┐     ┌──────────┐ │ ┌───┐ ┌──────────┐")
print("1: ┤ Hadamard ├─────┤ RY(θ1)  ├─┼─┤ X ├─┤ RZ(ω0)  ├─► Z expectation")
print("   └──────────┘     └──────────┘ │ └─┬─┘ └──────────┘")
print("                                  │   │   ┌──────────┐")
print("                                  └───┼───┤ RZ(ω1)  ├─► (not measured)")
print("                                      │   └──────────┘")
print("                                      └───┘")

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n" + "="*80)
print("FINAL SUMMARY REPORT - MPQA SENTIMENT ANALYSIS")
print("="*80)
print(f"Dataset: MPQA Opinion Corpus")
print(f"Total samples after preprocessing: {len(df)}")
print(f"Number of classes: {len(label_encoder.classes_)} ({', '.join(label_encoder.classes_)})")
print(f"Model Architecture: QBiLSTM-Q")
print(f"Base Encoder: {MODEL_NAME}")
print(f"Optimizer: AdamW")
print(f"Learning Rate: 2e-5")
print(f"Batch Size: 32")
print(f"Quantum Layer: ENABLED")
print(f"Quantum Circuit: 2-qubit with Hadamard, RX, RY, CNOT, RZ gates")
print(f"Total number of seeds evaluated: {len(SEEDS)}")
print(f"\n📊 Performance Metrics (mean ± std):")
print(f"   Average Best Val Accuracy: {stats['best_val_accuracy']['mean']:.4f} ± {stats['best_val_accuracy']['std']:.4f}")
print(f"   Average Final Val Accuracy: {stats['final_val_accuracy']['mean']:.4f} ± {stats['final_val_accuracy']['std']:.4f}")
print(f"   Average F1-Score: {stats['f1_score']['mean']:.4f} ± {stats['f1_score']['std']:.4f}")
print(f"   Average Precision: {stats['precision']['mean']:.4f} ± {stats['precision']['std']:.4f}")
print(f"   Average Recall: {stats['recall']['mean']:.4f} ± {stats['recall']['std']:.4f}")
print(f"\n📈 Best and Worst Performance:")
print(f"   Best overall accuracy: {max([r['best_val_accuracy'] for r in all_results]):.4f} (Seed {all_results[np.argmax([r['best_val_accuracy'] for r in all_results])]['seed']})")
print(f"   Worst overall accuracy: {min([r['best_val_accuracy'] for r in all_results]):.4f} (Seed {all_results[np.argmin([r['best_val_accuracy'] for r in all_results])]['seed']})")
print(f"\n🎯 Model Stability:")
print(f"   Standard deviation of best val acc: {stats['best_val_accuracy']['std']:.4f}")
print(f"   Range of best val acc: {stats['best_val_accuracy']['max'] - stats['best_val_accuracy']['min']:.4f}")
print("="*80)

print("\n✅ All results, plots, and statistics generated successfully!")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 68.3 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.6/935.6 kB 37.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 85.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 58.3 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 105.4 MB/s eta 0:00:0000:0100:01
# Device: cuda
#
# Loading MPQA dataset...
# README.md:   0%|          | 0.00/650 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# data/train-00000-of-00001-a7df005a1b0788(…):   0%|          | 0.00/141k [00:00<?, ?B/s]
# data/test-00000-of-00001-05fc5ca1c399669(…):   0%|          | 0.00/33.7k [00:00<?, ?B/s]
# data/dev-00000-of-00001-8814a3252cc44468(…):   0%|          | 0.00/6.19k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8603 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/256 [00:00<?, ? examples/s]
# Classes: {np.int64(0): 0, np.int64(1): 1}
# Class weights: {np.int64(0): np.float64(0.6847051198963059), np.int64(1): np.float64(1.8535087719298247)}
# config.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/371M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/198 [00:00<?, ?it/s]
# DebertaV2Model LOAD REPORT from: microsoft/deberta-v3-base
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# mask_predictions.classifier.weight      | UNEXPECTED |  |
# lm_predictions.lm_head.bias             | UNEXPECTED |  |
# lm_predictions.lm_head.dense.weight     | UNEXPECTED |  |
# mask_predictions.LayerNorm.weight       | UNEXPECTED |  |
# mask_predictions.dense.bias             | UNEXPECTED |  |
# mask_predictions.dense.weight           | UNEXPECTED |  |
# lm_predictions.lm_head.LayerNorm.bias   | UNEXPECTED |  |
# mask_predictions.LayerNorm.bias         | UNEXPECTED |  |
# lm_predictions.lm_head.dense.bias       | UNEXPECTED |  |
# lm_predictions.lm_head.LayerNorm.weight | UNEXPECTED |  |
# mask_predictions.classifier.bias        | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model hidden size: 768
#
# ================================================================================
# QBiLSTM-Q MODEL ON MPQA DATASET - MULTIPLE SEEDS
# Model: microsoft/deberta-v3-base (hidden size=768)
# Quantum Circuit: 2-qubit with Hadamard, RX, RY, CNOT, RZ gates
# Seeds to test: [42, 123, 256, 512, 999]
# ================================================================================
#
# ================================================================================
# TRAINING WITH SEED = 42
# Learning Rate: 2e-05, Batch Size: 32, Epochs: 10
# ================================================================================
# model.safetensors:   0%|          | 0.00/371M [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/198 [00:00<?, ?it/s]
# DebertaV2Model LOAD REPORT from: microsoft/deberta-v3-base
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# mask_predictions.classifier.weight      | UNEXPECTED |  |
# lm_predictions.lm_head.bias             | UNEXPECTED |  |
# lm_predictions.lm_head.dense.weight     | UNEXPECTED |  |
# mask_predictions.LayerNorm.weight       | UNEXPECTED |  |
# mask_predictions.dense.bias             | UNEXPECTED |  |
# mask_predictions.dense.weight           | UNEXPECTED |  |
# lm_predictions.lm_head.LayerNorm.bias   | UNEXPECTED |  |
# mask_predictions.LayerNorm.bias         | UNEXPECTED |  |
# lm_predictions.lm_head.dense.bias       | UNEXPECTED |  |
# lm_predictions.lm_head.LayerNorm.weight | UNEXPECTED |  |
# mask_predictions.classifier.bias        | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Epoch 1/10 | Train Loss: 0.6683 | Train Acc: 0.6617 | Val Loss: 0.4852 | Val Acc: 0.8303 | F1: 0.8334
# Epoch 2/10 | Train Loss: 0.4806 | Train Acc: 0.8428 | Val Loss: 0.4392 | Val Acc: 0.8675 | F1: 0.8675
# Epoch 3/10 | Train Loss: 0.4198 | Train Acc: 0.8641 | Val Loss: 0.4161 | Val Acc: 0.8699 | F1: 0.8712
# Epoch 4/10 | Train Loss: 0.3747 | Train Acc: 0.8803 | Val Loss: 0.3963 | Val Acc: 0.8622 | F1: 0.8654
# Epoch 5/10 | Train Loss: 0.3438 | Train Acc: 0.8908 | Val Loss: 0.4382 | Val Acc: 0.8717 | F1: 0.8734
# Epoch 6/10 | Train Loss: 0.3193 | Train Acc: 0.9043 | Val Loss: 0.4577 | Val Acc: 0.8717 | F1: 0.8722
# Epoch 7/10 | Train Loss: 0.3083 | Train Acc: 0.9110 | Val Loss: 0.4347 | Val Acc: 0.8770 | F1: 0.8786
# Epoch 8/10 | Train Loss: 0.3042 | Train Acc: 0.9116 | Val Loss: 0.4585 | Val Acc: 0.8764 | F1: 0.8771
# Epoch 9/10 | Train Loss: 0.3022 | Train Acc: 0.9135 | Val Loss: 0.4438 | Val Acc: 0.8723 | F1: 0.8743
# Epoch 10/10 | Train Loss: 0.2915 | Train Acc: 0.9184 | Val Loss: 0.4498 | Val Acc: 0.8758 | F1: 0.8773
#
# 📊 Final Results for Seed 42:
#    Best Val Acc: 0.8770
#    F1-Score: 0.8786
#    Precision: 0.8812
#    Recall: 0.8770
#
# ================================================================================
# TRAINING WITH SEED = 123
# Learning Rate: 2e-05, Batch Size: 32, Epochs: 10
# ================================================================================
# Loading weights:   0%|          | 0/198 [00:00<?, ?it/s]
# DebertaV2Model LOAD REPORT from: microsoft/deberta-v3-base
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# mask_predictions.classifier.weight      | UNEXPECTED |  |
# lm_predictions.lm_head.bias             | UNEXPECTED |  |
# lm_predictions.lm_head.dense.weight     | UNEXPECTED |  |
# mask_predictions.LayerNorm.weight       | UNEXPECTED |  |
# mask_predictions.dense.bias             | UNEXPECTED |  |
# mask_predictions.dense.weight           | UNEXPECTED |  |
# lm_predictions.lm_head.LayerNorm.bias   | UNEXPECTED |  |
# mask_predictions.LayerNorm.bias         | UNEXPECTED |  |
# lm_predictions.lm_head.dense.bias       | UNEXPECTED |  |
# lm_predictions.lm_head.LayerNorm.weight | UNEXPECTED |  |
# mask_predictions.classifier.bias        | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Epoch 1/10 | Train Loss: 0.6812 | Train Acc: 0.6252 | Val Loss: 0.5105 | Val Acc: 0.8415 | F1: 0.8419
# Epoch 2/10 | Train Loss: 0.4960 | Train Acc: 0.8375 | Val Loss: 0.4184 | Val Acc: 0.8291 | F1: 0.8365
# Epoch 3/10 | Train Loss: 0.4281 | Train Acc: 0.8654 | Val Loss: 0.3912 | Val Acc: 0.8723 | F1: 0.8744
# Epoch 4/10 | Train Loss: 0.3837 | Train Acc: 0.8812 | Val Loss: 0.3786 | Val Acc: 0.8634 | F1: 0.8679
# Epoch 5/10 | Train Loss: 0.3620 | Train Acc: 0.8907 | Val Loss: 0.3866 | Val Acc: 0.8705 | F1: 0.8724
# Epoch 6/10 | Train Loss: 0.3385 | Train Acc: 0.8979 | Val Loss: 0.3733 | Val Acc: 0.8717 | F1: 0.8747
# Epoch 7/10 | Train Loss: 0.3228 | Train Acc: 0.9049 | Val Loss: 0.3798 | Val Acc: 0.8723 | F1: 0.8753
# Epoch 8/10 | Train Loss: 0.3079 | Train Acc: 0.9121 | Val Loss: 0.3875 | Val Acc: 0.8764 | F1: 0.8790
# Epoch 9/10 | Train Loss: 0.3039 | Train Acc: 0.9132 | Val Loss: 0.3918 | Val Acc: 0.8770 | F1: 0.8789
# Epoch 10/10 | Train Loss: 0.2983 | Train Acc: 0.9145 | Val Loss: 0.3917 | Val Acc: 0.8734 | F1: 0.8760
#
# 📊 Final Results for Seed 123:
#    Best Val Acc: 0.8770
#    F1-Score: 0.8789
#    Precision: 0.8826
#    Recall: 0.8770
#
# ================================================================================
# TRAINING WITH SEED = 256
# Learning Rate: 2e-05, Batch Size: 32, Epochs: 10
# ================================================================================
# Loading weights:   0%|          | 0/198 [00:00<?, ?it/s]
# DebertaV2Model LOAD REPORT from: microsoft/deberta-v3-base
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# mask_predictions.classifier.weight      | UNEXPECTED |  |
# lm_predictions.lm_head.bias             | UNEXPECTED |  |
# lm_predictions.lm_head.dense.weight     | UNEXPECTED |  |
# mask_predictions.LayerNorm.weight       | UNEXPECTED |  |
# mask_predictions.dense.bias             | UNEXPECTED |  |
# mask_predictions.dense.weight           | UNEXPECTED |  |
# lm_predictions.lm_head.LayerNorm.bias   | UNEXPECTED |  |
# mask_predictions.LayerNorm.bias         | UNEXPECTED |  |
# lm_predictions.lm_head.dense.bias       | UNEXPECTED |  |
# lm_predictions.lm_head.LayerNorm.weight | UNEXPECTED |  |
# mask_predictions.classifier.bias        | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Epoch 1/10 | Train Loss: 0.6660 | Train Acc: 0.5542 | Val Loss: 0.4715 | Val Acc: 0.8539 | F1: 0.8551
# Epoch 2/10 | Train Loss: 0.4940 | Train Acc: 0.8348 | Val Loss: 0.4124 | Val Acc: 0.8522 | F1: 0.8577
# Epoch 3/10 | Train Loss: 0.4362 | Train Acc: 0.8679 | Val Loss: 0.3966 | Val Acc: 0.8723 | F1: 0.8752
# Epoch 4/10 | Train Loss: 0.3925 | Train Acc: 0.8758 | Val Loss: 0.3815 | Val Acc: 0.8545 | F1: 0.8596
# Epoch 5/10 | Train Loss: 0.3739 | Train Acc: 0.8848 | Val Loss: 0.3693 | Val Acc: 0.8888 | F1: 0.8898
# Epoch 6/10 | Train Loss: 0.3491 | Train Acc: 0.8938 | Val Loss: 0.3788 | Val Acc: 0.8829 | F1: 0.8847
# Epoch 7/10 | Train Loss: 0.3308 | Train Acc: 0.9045 | Val Loss: 0.3752 | Val Acc: 0.8817 | F1: 0.8834
# Epoch 8/10 | Train Loss: 0.3219 | Train Acc: 0.9062 | Val Loss: 0.3777 | Val Acc: 0.8859 | F1: 0.8864
# Epoch 9/10 | Train Loss: 0.3160 | Train Acc: 0.9098 | Val Loss: 0.3752 | Val Acc: 0.8823 | F1: 0.8839
# Epoch 10/10 | Train Loss: 0.3040 | Train Acc: 0.9145 | Val Loss: 0.3799 | Val Acc: 0.8841 | F1: 0.8854
#
# 📊 Final Results for Seed 256:
#    Best Val Acc: 0.8888
#    F1-Score: 0.8898
#    Precision: 0.8912
#    Recall: 0.8888
#
# ================================================================================
# TRAINING WITH SEED = 512
# Learning Rate: 2e-05, Batch Size: 32, Epochs: 10
# ================================================================================
# Loading weights:   0%|          | 0/198 [00:00<?, ?it/s]
# DebertaV2Model LOAD REPORT from: microsoft/deberta-v3-base
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# mask_predictions.classifier.weight      | UNEXPECTED |  |
# lm_predictions.lm_head.bias             | UNEXPECTED |  |
# lm_predictions.lm_head.dense.weight     | UNEXPECTED |  |
# mask_predictions.LayerNorm.weight       | UNEXPECTED |  |
# mask_predictions.dense.bias             | UNEXPECTED |  |
# mask_predictions.dense.weight           | UNEXPECTED |  |
# lm_predictions.lm_head.LayerNorm.bias   | UNEXPECTED |  |
# mask_predictions.LayerNorm.bias         | UNEXPECTED |  |
# lm_predictions.lm_head.dense.bias       | UNEXPECTED |  |
# lm_predictions.lm_head.LayerNorm.weight | UNEXPECTED |  |
# mask_predictions.classifier.bias        | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Epoch 1/10 | Train Loss: 0.6627 | Train Acc: 0.6705 | Val Loss: 0.4724 | Val Acc: 0.7895 | F1: 0.8000
# Epoch 2/10 | Train Loss: 0.4816 | Train Acc: 0.8503 | Val Loss: 0.4062 | Val Acc: 0.8628 | F1: 0.8664
# Epoch 3/10 | Train Loss: 0.4372 | Train Acc: 0.8626 | Val Loss: 0.4010 | Val Acc: 0.8758 | F1: 0.8777
# Epoch 4/10 | Train Loss: 0.3877 | Train Acc: 0.8840 | Val Loss: 0.3944 | Val Acc: 0.8776 | F1: 0.8799
# Epoch 5/10 | Train Loss: 0.3665 | Train Acc: 0.8934 | Val Loss: 0.3926 | Val Acc: 0.8859 | F1: 0.8873
# Epoch 6/10 | Train Loss: 0.3413 | Train Acc: 0.9021 | Val Loss: 0.4148 | Val Acc: 0.8823 | F1: 0.8841
# Epoch 7/10 | Train Loss: 0.3261 | Train Acc: 0.9084 | Val Loss: 0.4215 | Val Acc: 0.8853 | F1: 0.8860
# Epoch 8/10 | Train Loss: 0.3302 | Train Acc: 0.9092 | Val Loss: 0.4047 | Val Acc: 0.8829 | F1: 0.8851
# Epoch 9/10 | Train Loss: 0.3131 | Train Acc: 0.9123 | Val Loss: 0.4065 | Val Acc: 0.8811 | F1: 0.8829
# Epoch 10/10 | Train Loss: 0.3045 | Train Acc: 0.9166 | Val Loss: 0.4158 | Val Acc: 0.8841 | F1: 0.8854
#
# 📊 Final Results for Seed 512:
#    Best Val Acc: 0.8859
#    F1-Score: 0.8873
#    Precision: 0.8898
#    Recall: 0.8859
#
# ================================================================================
# TRAINING WITH SEED = 999
# Learning Rate: 2e-05, Batch Size: 32, Epochs: 10
# ================================================================================
# Loading weights:   0%|          | 0/198 [00:00<?, ?it/s]
# DebertaV2Model LOAD REPORT from: microsoft/deberta-v3-base
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# mask_predictions.classifier.weight      | UNEXPECTED |  |
# lm_predictions.lm_head.bias             | UNEXPECTED |  |
# lm_predictions.lm_head.dense.weight     | UNEXPECTED |  |
# mask_predictions.LayerNorm.weight       | UNEXPECTED |  |
# mask_predictions.dense.bias             | UNEXPECTED |  |
# mask_predictions.dense.weight           | UNEXPECTED |  |
# lm_predictions.lm_head.LayerNorm.bias   | UNEXPECTED |  |
# mask_predictions.LayerNorm.bias         | UNEXPECTED |  |
# lm_predictions.lm_head.dense.bias       | UNEXPECTED |  |
# lm_predictions.lm_head.LayerNorm.weight | UNEXPECTED |  |
# mask_predictions.classifier.bias        | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Epoch 1/10 | Train Loss: 0.6835 | Train Acc: 0.6193 | Val Loss: 0.5555 | Val Acc: 0.8332 | F1: 0.8265
# Epoch 2/10 | Train Loss: 0.4925 | Train Acc: 0.8311 | Val Loss: 0.4413 | Val Acc: 0.8610 | F1: 0.8623
# Epoch 3/10 | Train Loss: 0.4053 | Train Acc: 0.8715 | Val Loss: 0.4375 | Val Acc: 0.8699 | F1: 0.8708
# Epoch 4/10 | Train Loss: 0.3691 | Train Acc: 0.8799 | Val Loss: 0.4066 | Val Acc: 0.8705 | F1: 0.8731
# Epoch 5/10 | Train Loss: 0.3373 | Train Acc: 0.8960 | Val Loss: 0.4427 | Val Acc: 0.8764 | F1: 0.8773
# Epoch 6/10 | Train Loss: 0.3276 | Train Acc: 0.9000 | Val Loss: 0.4284 | Val Acc: 0.8734 | F1: 0.8747
# Epoch 7/10 | Train Loss: 0.3181 | Train Acc: 0.9034 | Val Loss: 0.4385 | Val Acc: 0.8782 | F1: 0.8788
# Epoch 8/10 | Train Loss: 0.3043 | Train Acc: 0.9087 | Val Loss: 0.4387 | Val Acc: 0.8723 | F1: 0.8740
# Epoch 9/10 | Train Loss: 0.2886 | Train Acc: 0.9164 | Val Loss: 0.4512 | Val Acc: 0.8711 | F1: 0.8728
# Epoch 10/10 | Train Loss: 0.2924 | Train Acc: 0.9135 | Val Loss: 0.4521 | Val Acc: 0.8723 | F1: 0.8738
#
# 📊 Final Results for Seed 999:
#    Best Val Acc: 0.8782
#    F1-Score: 0.8788
#    Precision: 0.8797
#    Recall: 0.8782
#
# ================================================================================
# STATISTICS ACROSS 5 SEEDS (Quantum Model)
# ================================================================================
#       best_val_accuracy  final_val_accuracy  final_train_accuracy  f1_score  \
# mean             0.8814              0.8779                0.9011    0.8827
# std              0.0050              0.0051                0.0107    0.0048
# min              0.8770              0.8723                0.8848    0.8786
# max              0.8888              0.8841                0.9132    0.8898
#
#       precision  recall
# mean     0.8849  0.8814
# std      0.0047  0.0050
# min      0.8797  0.8770
# max      0.8912  0.8888
#
# ================================================================================
# DETAILED RESULTS FOR ALL SEEDS
# ================================================================================
# Seed     Best Val Acc   Final Val Acc  Train Acc    Precision    Recall       F1-Score     Val Loss
# ----------------------------------------------------------------------------------------------------
# 42       0.8770         0.8758         0.9110       0.8812       0.8770       0.8786       0.4347
# 123      0.8770         0.8734         0.9132       0.8826       0.8770       0.8789       0.3918
# 256      0.8888         0.8841         0.8848       0.8912       0.8888       0.8898       0.3693
# 512      0.8859         0.8841         0.8934       0.8898       0.8859       0.8873       0.3926
# 999      0.8782         0.8723         0.9034       0.8797       0.8782       0.8788       0.4385
#
# ✅ Results saved to mpqa_multi_seed_results.csv
# ✅ Training curves saved to mpqa_training_curves.pdf
# ✅ Confusion matrices saved to mpqa_confusion_matrices.pdf
# ✅ Performance boxplot saved to mpqa_performance_boxplot.pdf
#
# ================================================================================
# QUANTUM CIRCUIT ARCHITECTURE
# ================================================================================
# Quantum circuit visualization not available: draw() got an unexpected keyword argument 'expansion_strategy'
#
# Quantum Circuit Diagram:
#    ┌──────────┐     ┌──────────┐
# 0: ┤ Hadamard ├─────┤ RX(θ0)  ├─┐
#    └──────────┘     └──────────┘ │
#    ┌──────────┐     ┌──────────┐ │ ┌───┐ ┌──────────┐
# 1: ┤ Hadamard ├─────┤ RY(θ1)  ├─┼─┤ X ├─┤ RZ(ω0)  ├─► Z expectation
#    └──────────┘     └──────────┘ │ └─┬─┘ └──────────┘
#                                   │   │   ┌──────────┐
#                                   └───┼───┤ RZ(ω1)  ├─► (not measured)
#                                       │   └──────────┘
#                                       └───┘
#
# ================================================================================
# FINAL SUMMARY REPORT - MPQA SENTIMENT ANALYSIS
# ================================================================================
# Dataset: MPQA Opinion Corpus
# Total samples after preprocessing: 8452
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_57/156179114.py in <cell line: 0>()
#     632 print(f"Dataset: MPQA Opinion Corpus")
#     633 print(f"Total samples after preprocessing: {len(df)}")
# --> 634 print(f"Number of classes: {len(label_encoder.classes_)} ({', '.join(label_encoder.classes_)})")
#     635 print(f"Model Architecture: QBiLSTM-Q")
#     636 print(f"Base Encoder: {MODEL_NAME}")
#
# TypeError: sequence item 0: expected str instance, numpy.int64 found
